# %%
import logging
logging.getLogger('py4j').setLevel(logging.ERROR)

# Install Tecton
import tecton
import pandas as pd

# Initialise Tecton
tecton.version.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Version: 0.0.20
# Git Commit: 5ac053ecfe180bae7d14d8968b22b932fd87cefa
# Build Datetime: 2020-09-24T07:49:43
# </div>
